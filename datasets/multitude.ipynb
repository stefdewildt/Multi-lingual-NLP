# %% [markdown]
# # MULTITuDE dataset demo

# %%
from multitude import (
    load_dataframe,
    filter_dataframe,
    MultitudeDataset,
)

df = load_dataframe()
df.head()
# Out:
#                                                 text  label       multi_label  \
# 0  Der Ausbruch des Coronavirus hat die Entwicklu...      1  text-davinci-003
# 1  Alex Azar was officially sworn in as the U.S. ...      1  text-davinci-003
# 2  Європейський союз вимагає зупинити розтрату ко...      1     gpt-3.5-turbo
# 3  Yesterday, hundreds of Zambian university stud...      1  text-davinci-003
# 4  In a narrow and highly watched vote, the US Se...      1             gpt-4
#
#    split language  length                          source
# 0   test       de     174   MULTITuDE_MassiveSumm_spiegel
# 1  train       en      57   MULTITuDE_MassiveSumm_voanews
# 2   test       uk     105  MULTITuDE_MassiveSumm_interfax
# 3  train       en     254   MULTITuDE_MassiveSumm_voanews
# 4  train       en     416   MULTITuDE_MassiveSumm_voanews

# %%
df.shape
# Out:
# (74081, 7)

# %%
df["language"].value_counts()
# Out:
# language
# en    29460
# es    11586
# ru    11578
# nl     2695
# ca     2691
# cs     2689
# de     2685
# zh     2683
# pt     2673
# ar     2673
# uk     2668
# Name: count, dtype: int64

# %%
df["multi_label"].value_counts()
# Out:
# multi_label
# gpt-3.5-turbo       8300
# gpt-4               8300
# text-davinci-003    8297
# alpaca-lora-30b     8290
# vicuna-13b          8287
# opt-66b             8229
# llama-65b           8229
# opt-iml-max-1.3b    8157
# human               7992
# Name: count, dtype: int64

# %%
df["split"].value_counts()
# Out:
# split
# train    44786
# test     29295
# Name: count, dtype: int64

# %% [markdown]
# ## Filtering

# %%
en_test_human = filter_dataframe(df, split="test", languages="en", binary_label=0)
en_test_human.shape
# Out:
# (277, 7)

# %%
de_gpt4 = filter_dataframe(df, languages="de", models="gpt-4")
de_gpt4.head()
# Out:
#                                                    text  label multi_label  \
# 191   Ein tragischer Unfall ereignete sich am Freita...      1       gpt-4
# 620   Kramsach, 20. August 2021 – Der Alpenverein, e...      1       gpt-4
# 1359  Hamburg, Deutschland - Erkan Uzun, der ehemali...      1       gpt-4
# 1950  Risikante Abschleppfahrt auf der A2 bei Brauns...      1       gpt-4
# 2046  Berlin - Der CDU-Parteitag hat am Freitag den ...      1       gpt-4
#
#      split language  length                            source
# 191   test       de     217        MULTITuDE_MassiveSumm_n-tv
# 620   test       de     183  MULTITuDE_MassiveSumm_meinbezirk
# 1359  test       de     222     MULTITuDE_MassiveSumm_spiegel
# 1950  test       de      81        MULTITuDE_MassiveSumm_welt
# 2046  test       de      63        MULTITuDE_MassiveSumm_welt

# %% [markdown]
# ## PyTorch Dataset

# %%
dataset = MultitudeDataset(split="train", languages=["en", "de"])
len(dataset), dataset[0]
# Out:
# (26969,
#  {'text': 'Alex Azar was officially sworn in as the U.S. Secretary of Health and Human Services (HHS) today. President Donald Trump administered the oath in a private ceremony at the White House.Azar, a lawyer and former pharmaceutical executive, replaces former Secretary Tom Price, who resigned last September."Alex will be a star for better healthcare and lower drug prices!"',
#   'label': 1,
#   'multi_label': 'text-davinci-003',
#   'split': 'train',
#   'language': 'en',
#   'length': 57,
#   'source': 'MULTITuDE_MassiveSumm_voanews'})

# %%
from torch.utils.data import DataLoader

loader = DataLoader(dataset, batch_size=4, shuffle=True)
next(iter(loader))
# Out:
# {'text': ["Lagos, Jan 6 (AP) Suspected Boko Haram militants in northeast Nigeria shot dead several people in a town, residents said Sunday, in one of the deadliest attacks in the region by the extremist group.The attack took place late Saturday night at Igbara-Akoko in the region's Yobe state, where the Islamic State's West Africa Province (ISWAP) is active.Brig. Gen. Sani Usman, a military spokesman, confirmed the deaths but gave no numbers.Usman said the attackers were being pursued from the town. He said more details would be released Monday.“The people have been shot,” said resident David Oluwale. “People are fleeing. We have no idea where they are hiding now.”Another resident, who gave her name as Olufowomo, said the suspected Boko Haram assailants arrived in several motorcycles, shot people indiscriminately and took away residents' cattle.Boko Haram, based in northeast Nigeria, is suspected to have killed more than 3,000 people and displaced 2 million since 2009.",
# ...
